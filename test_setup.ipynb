# %%
import sys

print("Python Executable Path:")
print(sys.executable)
print("\nStatus: Jupyter Notebook running successfully on CYB333-Conda!")
# Out:
# Python Executable Path:
# c:\Users\fabia\miniconda3\envs\CYB333-Conda\python.exe
#
# Status: Jupyter Notebook running successfully on CYB333-Conda!
